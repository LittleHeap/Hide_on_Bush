# %%
pip install -q tensorflow-model-optimization
# Out:
#      |████████████████████████████████| 174kB 9.3MB/s

# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/ML\ Project/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/ML Project

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import h5py
from PIL import Image
from matplotlib import pyplot as plt
from keras.preprocessing.image import array_to_img
import sys
import tensorflow_model_optimization as tfmot
import tempfile

# %%
B2_model = './github/models/multi_trigger_multi_target_bd_net.h5'
model_B2 = keras.models.load_model(B2_model)
B2_para = './github/models/multi_trigger_multi_target_bd_weights.h5'
model_B2.load_weights(B2_para)

model_B2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              [(None, 55, 47, 3)]  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 52, 44, 20)   980         input[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 26, 22, 20)   0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 24, 20, 40)   7240        pool_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 12, 10, 40)   0           conv_2[0][0]
# ...

# %%
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

# %%
def data_loader(filepath):
    data = h5py.File(filepath, 'r')
    x_data = np.array(data['data'])
    y_data = np.array(data['label'])
    x_data = x_data.transpose((0,2,3,1))
    return x_data / 255, y_data

clean_validation_data_path = './github/data/clean_validation_data.h5'
clean_test_data_path = './github/data/clean_test_data.h5'
sunglasses_poisoned_data_path = './github/data/sunglasses_poisoned_data.h5'

x_data_valid, y_data_valid = data_loader(clean_validation_data_path)
x_data_test, y_data_test = data_loader(clean_test_data_path)
x_data_backdoor, y_data_backdoor = data_loader(sunglasses_poisoned_data_path)

# %%
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.5,
                                    final_sparsity=0.8,
                                    begin_step=0,
                                    end_step=2000)
}

model_B2_after_pruning = prune_low_magnitude(model_B2, **pruning_params)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:2281: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '

# %%
model_B2_after_pruning.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_B2_after_pruning.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              [(None, 55, 47, 3)]  0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv_1 (Pru (None, 52, 44, 20)   1942        input[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_pool_1 (Pru (None, 26, 22, 20)   1           prune_low_magnitude_conv_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv_2 (Pru (None, 24, 20, 40)   14442       prune_low_magnitude_pool_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
logdir = tempfile.mkdtemp()

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep(),
  tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
  keras.callbacks.EarlyStopping(monitor="val_loss", patience=0)
]

model_B2_after_pruning.fit(x_data_valid, y_data_valid, epochs=3, callbacks=callbacks)
# Out:
# Epoch 1/3
# 361/361 [==============================] - 38s 93ms/step - loss: 0.5510 - accuracy: 0.8787
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/3
# 361/361 [==============================] - 34s 93ms/step - loss: 0.2319 - accuracy: 0.9372
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/3
# 361/361 [==============================] - 33s 92ms/step - loss: 0.2967 - accuracy: 0.9228
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy

# %%
B2_model = './github/models/multi_trigger_multi_target_bd_net.h5'
model_B2 = keras.models.load_model(B2_model)
B2_para = './github/models/multi_trigger_multi_target_bd_weights.h5'
model_B2.load_weights(B2_para)

model_B2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              [(None, 55, 47, 3)]  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 52, 44, 20)   980         input[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 26, 22, 20)   0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 24, 20, 40)   7240        pool_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 12, 10, 40)   0           conv_2[0][0]
# ...

# %%
def evaluate(model, x, y):
  pred = np.argmax(model.predict(x), axis=1)
  acc = np.mean(np.equal(pred, y))*100
  return acc

# %%
print('model_B2_after_pruning valid accuracy:', evaluate(model_B2_after_pruning, x_data_valid, y_data_valid))
# Out:
# model_B2_after_pruning valid accuracy: 95.86039663981987

# %%
print('model_B2_after_pruning test accuracy:', evaluate(model_B2_after_pruning, x_data_test, y_data_test))
# Out:
# model_B2_after_pruning test accuracy: 85.81449727201871

# %%
print('model_B2 valid accuracy:', evaluate(model_B2, x_data_valid, y_data_valid))
# Out:
# model_B2 valid accuracy: 96.26742876937733

# %%
print('model_B2 test accuracy:', evaluate(model_B2, x_data_test, y_data_test))
# Out:
# model_B2 test accuracy: 96.00935307872174

# %%
p1 = np.argmax(model_B2.predict(x_data_backdoor), axis=1)
p2 = np.argmax(model_B2_after_pruning.predict(x_data_backdoor), axis=1)
print(p1)
print(p2)
n = 0
for a, b in zip(p1, p2):
  if a != b:
    n += 1
print('The number of cases we identify as backdoor data in the sunglasses dataset is:', n)
# Out:
# [8 8 8 ... 8 8 8]
# [  34 1152 1152 ...   34 1152  913]
# The number of cases we identify as backdoor data in the sunglasses dataset is: 12818

# %%
def repaired_B2(x):
  y1 = np.argmax(model_B2.predict(x), axis=1)
  y2 = np.argmax(model_B2_after_pruning.predict(x), axis=1)
  res = []
  for i in range(len(x)):
    if y1[i] == y2[i]:
      res.append(y1[i])
    else:
      res.append(1283)
  return np.array(res)

# %%
repaire_B2_valid_res = repaired_B2(x_data_valid)
repaire_B2_valid_acc = np.mean(np.equal(repaire_B2_valid_res, y_data_valid))*100
print('repaired B2 valid accuracy: ',repaire_B2_valid_acc)
# Out:
# repaired B2 valid accuracy:  92.56083831298173

# %%
repaire_B2_test_res = repaired_B2(x_data_test)
repaire_B2_test_acc = np.mean(np.equal(repaire_B2_test_res, y_data_test))*100
print('repaired B2 test accuracy: ',repaire_B2_test_acc)
# Out:
# repaired B2 test accuracy:  84.08417770849572

# %%
model_B2_after_pruning.save('./Pruned_B2.h5')
